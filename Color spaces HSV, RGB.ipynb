# %%
import cv2
import numpy as np

# %%
img= cv2.imread('/Users/shashank/Desktop/input.jpg')

# %%
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
B,G,R= img[0,0]

# %%
print(B,G,R)
# Out:
# 12 18 29

# %%
gray_img= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
gray_img[0,0]
# Out:
# 21

# %%
hsv_img= cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

# %%
cv2.imshow('HSV image',hsv_img)

# %%
Hue_channel=hsv_img[:,:,0]
Hue_channel
# Out:
# array([[11,  9,  9, ...,  5,  5,  5],
#        [11,  9,  9, ...,  5,  5,  5],
#        [11,  9,  9, ...,  5,  5,  5],
#        ...,
#        [11, 11, 11, ...,  8,  8,  8],
#        [11, 11, 11, ...,  8,  8,  8],
#        [11, 11, 11, ...,  8,  8,  8]], dtype=uint8)

# %%
Saturation_channel=hsv_img[:,:,1]
Saturation_channel
# Out:
# array([[149, 156, 162, ..., 114, 114, 114],
#        [149, 156, 156, ..., 114, 114, 114],
#        [149, 156, 156, ..., 114, 114, 114],
#        ...,
#        [170, 170, 170, ..., 134, 131, 128],
#        [185, 185, 185, ..., 134, 131, 128],
#        [185, 185, 204, ..., 134, 134, 131]], dtype=uint8)

# %%
Value_channel=hsv_img[:,:,2]
Value_channel
# Out:
# array([[29, 31, 30, ..., 38, 38, 38],
#        [29, 31, 31, ..., 38, 38, 38],
#        [29, 31, 31, ..., 38, 38, 38],
#        ...,
#        [12, 12, 12, ..., 38, 39, 40],
#        [11, 11, 11, ..., 38, 39, 40],
#        [11, 11, 10, ..., 38, 38, 39]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.imshow(hsv_img)
plt.show
# Out:
# <function matplotlib.pyplot.show>
